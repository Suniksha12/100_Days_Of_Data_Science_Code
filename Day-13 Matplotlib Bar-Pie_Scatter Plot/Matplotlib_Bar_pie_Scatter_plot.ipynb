# %% [markdown]
# # **Scatter Plot**

# %%
#importing libraries

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 12, 5, 8, 7])

plt.scatter(x,y)

plt.xlabel('X-axis label')
plt.ylabel('Y-axis Label')
plt.title('Scatter PLot')
plt.show()

# %%
#color each Dot
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 12, 5, 8, 7])
colors = np.array(["red","green","blue","pink","gray"])
plt.scatter(x,y, c=colors)

plt.xlabel('X-axis label')
plt.ylabel('y-axis Label')
plt.title('Scatter Plot')
plt.show()

# %%
#colormap
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 12, 5, 8, 7])
colors = np.array([0,10,20,30,40])
plt.scatter(x,y,c=colors,cmap='viridis')

plt.colorbar()
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot')
plt.show()

# %%
#size alpha
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 12, 5, 8, 7])
sizes = np.array([20,50,100,200,500])
plt.scatter(x,y,alpha = 0.8 , s= sizes)

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis label')
plt.title('Scatter Plot')
plt.show()

# %%
#combining color size and alpha
#creating random arrays with 100 values for x points , y - points , colors and sizes

x = np.random.randint(100,size=(100))
y = np.random.randint(100,size=(100))
colors = np.random.randint(100,size=(100))
sizes = 10*np.random.randint(100,size=(100))

plt.scatter(x,y,c = colors , s= sizes , alpha = 0.5,cmap = 'spring')

plt.colorbar()

plt.show()

# %% [markdown]
# # **Matplotlib Bars Plots**

# %%
#creating bars
x = np.array([' A', ' B', ' C', ' D'])
y = np.array([25, 40, 30, 50])

plt.bar(x,y)

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar plot')
plt.show()

# %%
#horizontal Bars
x = np.array([' A', ' B', ' C', ' D'])
y = np.array([25, 40, 30, 50])

plt.barh(x,y,color="hotpink")
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.show()

# %%
#bar width
x = np.array([' A', ' B', ' C', ' D'])
y = np.array([25, 40, 30, 50])

plt.bar(x,y,width = 0.2)

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.show()

# %% [markdown]
# # **Histograms**
#
# Graph showing frequency Distributions.

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
score= np.array([54, 37, 57, 43, 72, 43, 91, 43, 93, 49,
               60, 69, 62, 73, 42, 63, 82, 83, 81, 33,
               70, 50, 81, 69, 87, 45, 85, 55, 53, 60,
               53, 66, 53, 79, 79, 69, 55, 87, 66, 49,
               73, 41, 75, 60, 90, 50, 44, 47, 78, 79,
               78, 48, 84, 68, 56, 64, 83, 48, 86, 63,
               59, 87, 42, 68, 47, 98, 52, 72, 62, 66,
               83, 47, 34, 84, 64, 98, 95, 57, 82, 52,
               56, 74, 84, 83, 65, 31, 89, 75, 79, 77,
               78, 68, 78, 48, 88, 62, 88, 74, 74, 78])


plt.hist(score, bins=20)
plt.xlabel("_Scores")
plt.ylabel("_Students")
plt.title("Scores in the Math class histogram")

plt.show()

# %% [markdown]
# # **Matplotlib Pie Charts**

# %%
y = np.array([35, 25, 25, 15])
fruits = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y,labels = fruits , startangle =90)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
explod = [0.2,0,0,0]

plt.pie(y,labels = fruits, explode = explod , shadow = True)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
color = ["black","hotpink","b","#4CAF50"]

plt.pie(y,labels = fruits, colors = color)
plt.legend(title="Four Fruits")
plt.show()
